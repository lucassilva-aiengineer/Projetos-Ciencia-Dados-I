# %%
# %%capture
# !pip install pandas matplotlib numpy

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/content/Crime_Reports_austin_texas.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700085 entries, 0 to 700084
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Incident Number              700085 non-null  int64
#  1   Highest Offense Description  700085 non-null  object
#  2   Highest Offense Code         700084 non-null  float64
#  3   Family Violence              700084 non-null  object
#  4   Occurred Date Time           700039 non-null  object
#  5   Occurred Date                700084 non-null  object
#  6   Occurred Time                700040 non-null  float64
#  7   Report Date Time             700083 non-null  object
#  8   Report Date                  700084 non-null  object
#  9   Report Time                  700083 non-null  float64
#  10  Location Type                688821 non-null  object
#  11  Council District             673569 non-null  float64
#  12  APD Sector                   700083 non-null  object
#  13  APD District                 700082 non-null  object
#  14  Clearance Status             315724 non-null  object
#  15  Clearance Date               565812 non-null  object
#  16  UCR Category                 251919 non-null  object
#  17  Category Description         251919 non-null  object
#  18  Census Block Group           665202 non-null  float64
# dtypes: float64(5), int64(1), object(13)
# memory usage: 101.5+ MB

# %%
df.head(2)
# Out:
#    Incident Number Highest Offense Description  Highest Offense Code  \
# 0    2002923330284          FAMILY DISTURBANCE                3400.0
# 1    2003920010029              DEADLY CONDUCT                 408.0
#
#   Family Violence Occurred Date Time Occurred Date  Occurred Time  \
# 0               N  01/29/2003  05:30    01/29/2003          530.0
# 1               N  01/01/2003  00:01    01/01/2003            1.0
#
#     Report Date Time Report Date  Report Time     Location Type  \
# 0  11/29/2002  05:30  11/29/2002        530.0  RESIDENCE / HOME
# 1  01/01/2003  00:01  01/01/2003          1.0  RESIDENCE / HOME
#
#    Council District APD Sector APD District Clearance Status Clearance Date  \
# 0               6.0         AD            3                N            NaN
# 1               4.0         ID            4                N            NaN
#
#   UCR Category Category Description  Census Block Group
# 0          NaN                  NaN        4.530341e+09
# 1          13A   Aggravated Assault        4.530021e+09

# %%
df.tail(2)
# Out:
#         Incident Number Highest Offense Description  Highest Offense Code  \
# 700083      20085034927       BURGLARY OF RESIDENCE                 500.0
# 700084      20081871562                        ASSA                   NaN
#
#        Family Violence Occurred Date Time Occurred Date  Occurred Time  \
# 700083               N  07/07/2008  12:20    07/07/2008         1220.0
# 700084             NaN                NaN           NaN            NaN
#
#          Report Date Time Report Date  Report Time     Location Type  \
# 700083  07/07/2008  12:20  07/07/2008       1220.0  RESIDENCE / HOME
# 700084                NaN         NaN          NaN               NaN
#
#         Council District APD Sector APD District Clearance Status  \
# 700083               9.0         BA            1              NaN
# 700084               NaN        NaN          NaN              NaN
#
#        Clearance Date UCR Category Category Description  Census Block Group
# 700083     07/23/2008          220             Burglary        4.530005e+09
# 700084            NaN          NaN                  NaN                 NaN

# %%
df.sample(2)
# Out:
#         Incident Number Highest Offense Description  Highest Offense Code  \
# 509000       2007630334          ROBBERY BY ASSAULT                 303.0
# 533158      20075022352            THEFT OF BICYCLE                 609.0
#
#        Family Violence Occurred Date Time Occurred Date  Occurred Time  \
# 509000               N  03/04/2007  02:57    03/04/2007          257.0
# 533158               N  05/04/2007  02:30    05/04/2007          230.0
#
#          Report Date Time Report Date  Report Time  \
# 509000  03/04/2007  02:57  03/04/2007        257.0
# 533158  05/05/2007  14:08  05/05/2007       1408.0
#
#                        Location Type  Council District APD Sector  \
# 509000  COMMERCIAL / OFFICE BUILDING               4.0         ID
# 533158              RESIDENCE / HOME               9.0         BA
#
#        APD District Clearance Status Clearance Date UCR Category  \
# 509000            8              NaN     06/08/2007          120
# 533158            5              NaN     05/07/2007          23H
#
#        Category Description  Census Block Group
# 509000              Robbery        4.530400e+09
# 533158                Theft        4.530003e+09

# %%
df.describe()
# Out:
#            YearStart        YearEnd  Response     DataValue  DataValueAlt  \
# count  105644.000000  105644.000000       0.0  7.282200e+04  7.282200e+04
# mean     2018.411552    2019.145782       NaN  9.931762e+02  1.111857e+03
# std         1.336428       0.377262       NaN  2.107431e+04  2.562854e+04
# min      2015.000000    2019.000000       NaN  0.000000e+00  0.000000e+00
# 25%      2019.000000    2019.000000       NaN  1.380000e+01  1.380000e+01
# 50%      2019.000000    2019.000000       NaN  2.940000e+01  2.940000e+01
# 75%      2019.000000    2019.000000       NaN  6.770000e+01  6.770000e+01
# max      2022.000000    2022.000000       NaN  2.925456e+06  2.925456e+06
#
#        LowConfidenceLimit  HighConfidenceLimit  StratificationCategory2  \
# count        63058.000000         63058.000000                      0.0
# mean            44.503325            53.938003                      NaN
# std             82.270736            86.676737                      NaN
# min              0.000000             0.000000                      NaN
# 25%             10.000000            15.400000                      NaN
# 50%             21.090000            30.800000                      NaN
# 75%             43.100000            56.500000                      NaN
# max           1300.800000          1357.500000                      NaN
#
#        Stratification2  StratificationCategory3  Stratification3  \
# count              0.0                      0.0              0.0
# mean               NaN                      NaN              NaN
# std                NaN                      NaN              NaN
# min                NaN                      NaN              NaN
# 25%                NaN                      NaN              NaN
# 50%                NaN                      NaN              NaN
# 75%                NaN                      NaN              NaN
# max                NaN                      NaN              NaN
#
#          LocationID  ResponseID  StratificationCategoryID2  StratificationID2  \
# count  105644.00000         0.0                        0.0                0.0
# mean       29.83611         NaN                        NaN                NaN
# std        17.20104         NaN                        NaN                NaN
# min         1.00000         NaN                        NaN                NaN
# 25%        16.00000         NaN                        NaN                NaN
# 50%        29.00000         NaN                        NaN                NaN
# 75%        42.00000         NaN                        NaN                NaN
# max        78.00000         NaN                        NaN                NaN
#
#        StratificationCategoryID3  StratificationID3
# count                        0.0                0.0
# mean                         NaN                NaN
# std                          NaN                NaN
# min                          NaN                NaN
# 25%                          NaN                NaN
# 50%                          NaN                NaN
# 75%                          NaN                NaN
# max                          NaN                NaN

# %%
df.head(2)
# Out:
#    Incident Number Highest Offense Description  Highest Offense Code  \
# 0    2002923330284          FAMILY DISTURBANCE                3400.0
# 1    2003920010029              DEADLY CONDUCT                 408.0
#
#   Family Violence Occurred Date Time Occurred Date  Occurred Time  \
# 0               N  01/29/2003  05:30    01/29/2003          530.0
# 1               N  01/01/2003  00:01    01/01/2003            1.0
#
#     Report Date Time Report Date  Report Time     Location Type  \
# 0  11/29/2002  05:30  11/29/2002        530.0  RESIDENCE / HOME
# 1  01/01/2003  00:01  01/01/2003          1.0  RESIDENCE / HOME
#
#    Council District APD Sector APD District Clearance Status Clearance Date  \
# 0               6.0         AD            3                N            NaN
# 1               4.0         ID            4                N            NaN
#
#   UCR Category Category Description  Census Block Group
# 0          NaN                  NaN        4.530341e+09
# 1          13A   Aggravated Assault        4.530021e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700085 entries, 0 to 700084
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Incident Number              700085 non-null  int64
#  1   Highest Offense Description  700085 non-null  object
#  2   Highest Offense Code         700084 non-null  float64
#  3   Family Violence              700084 non-null  object
#  4   Occurred Date Time           700039 non-null  object
#  5   Occurred Date                700084 non-null  object
#  6   Occurred Time                700040 non-null  float64
#  7   Report Date Time             700083 non-null  object
#  8   Report Date                  700084 non-null  object
#  9   Report Time                  700083 non-null  float64
#  10  Location Type                688821 non-null  object
#  11  Council District             673569 non-null  float64
#  12  APD Sector                   700083 non-null  object
#  13  APD District                 700082 non-null  object
#  14  Clearance Status             315724 non-null  object
#  15  Clearance Date               565812 non-null  object
#  16  UCR Category                 251919 non-null  object
#  17  Category Description         251919 non-null  object
#  18  Census Block Group           665202 non-null  float64
# dtypes: float64(5), int64(1), object(13)
# memory usage: 101.5+ MB

# %%
df["Occurred Date Time"] = pd.to_datetime(df["Occurred Date Time"], format= "%m/%d/%Y %H:%M")

# %%
df["dia ocorrido"] = df["Occurred Date Time"].dt.day
df["mes ocorrido"] = df["Occurred Date Time"].dt.month
df["ano ocorrido"] = df["Occurred Date Time"].dt.year
df["hora ocorrido"] = df["Occurred Date Time"].dt.hour

# %%
quantidades_diarias = df["dia ocorrido"].value_counts()
quantidades_diarias = quantidades_diarias.reset_index()

# %%
quantidades_diarias.head(2)
# Out:
#    dia ocorrido  count
# 0           1.0  28276
# 1          15.0  24029

# %%
quantidades_diarias.columns
# Out:
# Index(['dia ocorrido', 'count'], dtype='object')

# %%
plt.scatter(quantidades_diarias["dia ocorrido"],
            quantidades_diarias["count"],
            color= "green")

plt.title("Relação Crimes dia do mês")

plt.show()

# %%
# Quais os dias da semana mais perigosos em austin.
# Eu acredito que seja o final de semana


df["dia semana"] = df["Occurred Date Time"].dt.day_name()

# %%
df["dia semana"].head()
# Out:
# 0    Wednesday
# 1    Wednesday
# 2    Wednesday
# 3    Wednesday
# 4    Wednesday
# Name: dia semana, dtype: object

# %%
contagem_dias_semana = df["dia semana"].value_counts()
contagem_dias_semana = contagem_dias_semana.reset_index()

# %%
contagem_dias_semana.head()
# Out:
#   dia semana   count
# 0     Friday  105811
# 1   Saturday  105092
# 2   Thursday  101002
# 3  Wednesday   97860
# 4     Monday   97224

# %%
plt.bar(np.array([dia[:6] for dia in  list(contagem_dias_semana["dia semana"])]),
        contagem_dias_semana["count"],
        color= "lightgreen",
        edgecolor= 'black')


plt.title("Dia da semana")
plt.grid(True,
         alpha= 0.8)


plt.show()

# %%
# Que tal vermos em porcentagem

plt.pie(contagem_dias_semana["count"],
        labels= contagem_dias_semana["dia semana"],
        autopct= "%.2f%%")

plt.title("Distribuição dos crimes cometidos em Austin")

plt.show()


# É clara a distribuição com poucas diferenças.

# Dia com maior número de casos: Friday, Sexta-Feira.
# Dia com menor número de casos: Sunday, Domingo.

# Será que isso se repete em outras cidades?
# Será que isso também acontece quanto ao registro das ocorrências?

# %%
# Lembre-se A missão do ciêntista de dados é extrair conhecimento de dados desorganizados.
# O ciêntista de dados é aquele que sabe mais de ciência da computação que um estatístico e mais
# sobre estatística que um ciêntista da computação.
